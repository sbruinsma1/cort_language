# %%
from language import figures as fig

# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
fig.fig1()
# Out:
# F stat for cloze slope: 2.0931779235156287, p-value: 0.15832676759127068
# F stat for cloze RT diff: 0.042751270715655605, p-value: 0.8375912983327986
# F stat for CoRT slope: 0.0009082736633617055, p-value: 0.9761569372796227
# F stat for CoRT RT diff: 1.983302829200662, p-value: 0.16932250108318636

# %%
fig.figS1()

# %%
fig.figS2()

# %%
fig.figS3()
