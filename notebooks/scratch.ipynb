# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from language import visualize_task as vis

# %reload_ext autoreload
# %autoreload 2

# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
vis.plotting_style()

# %%
# PLOT RT

df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08',  'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=1,
                        remove_outliers=True
                       )

ax = vis.plot_rt(df, plot_type='line', hue='group');

# %%
# PLOT RT

df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08',  'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=1,
                        remove_outliers=True
                       )

ax = vis.plot_rt(df, x='group', plot_type='bar', hue='cloze');

# %%
# PLOT RT

df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08',  'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=1,
                        remove_outliers=True
                       )

ax = vis.plot_rt(df, x='group', plot_type='bar', hue='CoRT');

# %%
# PLOT ACCURACY

df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08',  'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=None,
                        remove_outliers=True
                       )

ax = vis.plot_acc(df, plot_type='line', hue='group');

# %%
# PLOT ACCURACY

df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08',  'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=None,
                        remove_outliers=True
                       )

ax = vis.plot_acc(df, x='group', plot_type='bar', hue='cloze');

# %%
# PLOT ACCURACY

df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08',  'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=None,
                        remove_outliers=True
                       )

ax = vis.plot_acc(df, x='group', plot_type='bar', hue='CoRT');

# %%
# PLOT item analysis (RT)

df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08', 'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=1
                       )

vis.item_analysis(df, y='rt')

# %%
# PLOT Ratings (CoRT)

df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08', 'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=1
                       )

vis.scatterplot_rating(df, x='CoRT')
# Out:
# <AxesSubplot:xlabel='CoRT (mean)', ylabel='Mean RT'>

# %%
# PLOT Ratings (cloze)

df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08', 'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=1
                       )

vis.scatterplot_rating(df, x='cloze')
# Out:
# <AxesSubplot:xlabel='Cloze (mean)', ylabel='Mean RT'>

# %%
# BOXPLOT - cloze

df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08', 'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=1
                       )

vis.plot_rt(df, x='cloze', hue='group', plot_type='box');

# %%
# BOXPLOT - CoRT

df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08', 'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=1,
                       )

vis.plot_rt(df, x='CoRT', hue='group', plot_type='box');

# %%
df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08', 'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=1,
                        remove_outliers=True
                       )

vis.plot_slope(df, y='CoRT')
# Out:
# F stat: 0.02851793969135152, p-value: 0.8660042508345549

# %%
df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08', 'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=1,
                        remove_outliers=True
                       )

vis.rt_diff(df, y='CoRT')

# %%
df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08', 'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=1
                       )

vis.rt_diff(df, y='cloze')

# %%
# interaction between cloze and CoRT

df = vis.load_dataframe(bad_subjs=['p06', 'p11', 'p08', 'c19'],
                        trial_type='meaningful',
                        attempt=None,
                        correct=1
                       )

vis.
